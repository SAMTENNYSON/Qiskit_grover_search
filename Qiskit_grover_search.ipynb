# %%
# !pip install qiskit qiskit_aer
# Out:
# Requirement already satisfied: qiskit in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (2.2.1)
# Requirement already satisfied: qiskit_aer in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (0.17.2)
# Requirement already satisfied: rustworkx>=0.15.0 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit) (2.3.3)
# Requirement already satisfied: scipy>=1.5 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit) (1.16.2)
# Requirement already satisfied: dill>=0.3 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit_aer) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\7th_sem\vac_quantum_programming\qc_venv\lib\site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.17.0)

# %%
# Grover's Search Algorithm using Qiskit 2.x

from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# %%
def oracle(qc, n, marked_state):
    """Constructs the oracle for the marked state."""
    for i, bit in enumerate(marked_state):
        if bit == "0":
            qc.x(i)
    qc.h(n - 1)
    qc.mcx(list(range(n - 1)), n - 1)  # use mcx() in Qiskit 2.x
    qc.h(n - 1)
    for i, bit in enumerate(marked_state):
        if bit == "0":
            qc.x(i)

# %%
def diffuser(qc, n):
    """Implements the Grover diffuser."""
    qc.h(range(n))
    qc.x(range(n))
    qc.h(n - 1)
    qc.mcx(list(range(n - 1)), n - 1)
    qc.h(n - 1)
    qc.x(range(n))
    qc.h(range(n))

def grover_search(marked_state):
    """Builds Grover's search circuit for a given marked state."""
    n = len(marked_state)
    qc = QuantumCircuit(n, n)
    qc.h(range(n))
    oracle(qc, n, marked_state)
    diffuser(qc, n)
    qc.measure(range(n), range(n))
    return qc

# %%
def run_grover(qc):
    """Executes the Grover circuit and displays the result."""
    simulator = AerSimulator()
    compiled_circuit = transpile(qc, simulator)
    result = simulator.run(compiled_circuit, shots=1024).result()
    counts = result.get_counts()
    plot_histogram(counts)
    plt.show()

if __name__ == "__main__":
    marked_state = "101"
    print("Searching for marked state:", marked_state)
    qc = grover_search(marked_state)
    print(qc.draw(fold=-1))
    run_grover(qc)
# Out:
# Searching for marked state: 101
#      ┌───┐          ┌───┐┌───┐               ┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├─────┤M├──────
#      ├───┤┌───┐  │  ├───┤├───┤┌───┐       │  ├───┤├───┤     └╥┘┌─┐
# q_1: ┤ H ├┤ X ├──■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├──────╫─┤M├───
#      ├───┤├───┤┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤┌───┐ ║ └╥┘┌─┐
# q_2: ┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─╫──╫─┤M├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘ ║  ║ └╥┘
# c: 3/════════════════════════════════════════════════════════╩══╩══╩═
#                                                              0  1  2

# %% [markdown]
# # Task 1: Change the marked state
# Try different marked states such as 001, 111, or 010 and observe the output histogram.

# %%
if __name__ == "__main__":
    # Try different marked states by changing this value
    for marked_state in ["001", "111", "010"]:
        print(f"\nSearching for marked state: {marked_state}")
        qc = grover_search(marked_state)
        print(qc.draw(fold=-1))
        run_grover(qc)
# Out:
# Searching for marked state: 001
#      ┌───┐┌───┐     ┌───┐┌───┐┌───┐          ┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├┤ X ├──■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├─────┤M├──────
#      ├───┤├───┤  │  ├───┤├───┤├───┤       │  ├───┤├───┤     └╥┘┌─┐
# q_1: ┤ H ├┤ X ├──■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├──────╫─┤M├───
#      ├───┤├───┤┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤┌───┐ ║ └╥┘┌─┐
# q_2: ┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─╫──╫─┤M├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘ ║  ║ └╥┘
# c: 3/════════════════════════════════════════════════════════╩══╩══╩═
#                                                              0  1  2
#
# Searching for marked state: 111
#      ┌───┐          ┌───┐┌───┐               ┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├─────┤M├──────
#      ├───┤       │  ├───┤├───┤            │  ├───┤├───┤     └╥┘┌─┐
# q_1: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├──────╫─┤M├───
#      ├───┤┌───┐┌─┴─┐├───┤├───┤┌───┐┌───┐┌─┴─┐├───┤├───┤┌───┐ ║ └╥┘┌─┐
# q_2: ┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─╫──╫─┤M├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘ ║  ║ └╥┘
# c: 3/════════════════════════════════════════════════════════╩══╩══╩═
#                                                              0  1  2
#
# Searching for marked state: 010
#      ┌───┐┌───┐          ┌───┐┌───┐┌───┐               ┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├────────────■──┤ X ├┤ H ├─────┤M├──────
#      ├───┤└───┘       │  ├───┤├───┤└───┘            │  ├───┤├───┤     └╥┘┌─┐
# q_1: ┤ H ├────────────■──┤ H ├┤ X ├─────────────────■──┤ X ├┤ H ├──────╫─┤M├───
#      ├───┤┌───┐┌───┐┌─┴─┐├───┤├───┤┌───┐┌───┐┌───┐┌─┴─┐├───┤├───┤┌───┐ ║ └╥┘┌─┐
# q_2: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─╫──╫─┤M├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘ ║  ║ └╥┘
# c: 3/══════════════════════════════════════════════════════════════════╩══╩══╩═
#                                                                        0  1  2

# %% [markdown]
# # Task 2: Modify the number of qubits
# Extend the algorithm to 4 qubits and update the oracle and diffuser accordingly.

# %%
if __name__ == "__main__":
    marked_state = "1101"  # 4-qubit marked state
    print("Searching for marked state:", marked_state)
    qc = grover_search(marked_state)
    print(qc.draw(fold=-1))
    run_grover(qc)
# Out:
# Searching for marked state: 1101
#      ┌───┐          ┌───┐┌───┐               ┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├─────┤M├─────────
#      ├───┤       │  ├───┤├───┤            │  ├───┤├───┤     └╥┘┌─┐
# q_1: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├──────╫─┤M├──────
#      ├───┤┌───┐  │  ├───┤├───┤┌───┐       │  ├───┤├───┤      ║ └╥┘┌─┐
# q_2: ┤ H ├┤ X ├──■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├──────╫──╫─┤M├───
#      ├───┤├───┤┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤┌───┐ ║  ║ └╥┘┌─┐
# q_3: ┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─╫──╫──╫─┤M├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘ ║  ║  ║ └╥┘
# c: 4/════════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                              0  1  2  3

# %% [markdown]
# # Task 3: Add multiple iterations
# Run the oracle and diffuser steps multiple times to increase the probability of finding the marked state.

# %%
# --- Task 3: Multiple Grover iterations ---

def grover_search_iterations(marked_state, iterations=2):
    """Build Grover's search circuit with multiple iterations."""
    n = len(marked_state)
    qc = QuantumCircuit(n, n)
    qc.h(range(n))  # Initialization

    for _ in range(iterations):
        oracle(qc, n, marked_state)
        diffuser(qc, n)

    qc.measure(range(n), range(n))
    return qc

if __name__ == "__main__":
    marked_state = "101"
    print("Searching for marked state:", marked_state)
    qc = grover_search_iterations(marked_state, iterations=3)
    print(qc.draw(fold=-1))
    run_grover(qc)
# Out:
# Searching for marked state: 101
#      ┌───┐          ┌───┐┌───┐               ┌───┐┌───┐               ┌───┐┌───┐               ┌───┐┌───┐               ┌───┐┌───┐               ┌───┐┌───┐     ┌─┐
# q_0: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├────────────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├────────────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├─────┤M├──────
#      ├───┤┌───┐  │  ├───┤├───┤┌───┐       │  ├───┤├───┤┌───┐       │  ├───┤├───┤┌───┐       │  ├───┤├───┤┌───┐       │  ├───┤├───┤┌───┐       │  ├───┤├───┤     └╥┘┌─┐
# q_1: ┤ H ├┤ X ├──■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├──────╫─┤M├───
#      ├───┤├───┤┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤┌───┐ ║ └╥┘┌─┐
# q_2: ┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─╫──╫─┤M├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘ ║  ║ └╥┘
# c: 3/════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩══╩═
#                                                                                                                                                                  0  1  2

# %% [markdown]
# # Task 4: Circuit Visualization
# Use qc.draw('mpl') to visualize the circuit structure in the notebook.

# %%
# Visualize the circuit in text form
print(qc.draw())
# Out:
#      ┌───┐          ┌───┐┌───┐               ┌───┐┌───┐               ┌───┐»
# q_0: ┤ H ├───────■──┤ H ├┤ X ├────────────■──┤ X ├┤ H ├────────────■──┤ H ├»
#      ├───┤┌───┐  │  ├───┤├───┤┌───┐       │  ├───┤├───┤┌───┐       │  ├───┤»
# q_1: ┤ H ├┤ X ├──■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├»
#      ├───┤├───┤┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤»
# q_2: ┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├»
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘»
# c: 3/══════════════════════════════════════════════════════════════════════»
#                                                                            »
# «     ┌───┐               ┌───┐┌───┐               ┌───┐┌───┐               »
# «q_0: ┤ X ├────────────■──┤ X ├┤ H ├────────────■──┤ H ├┤ X ├────────────■──»
# «     ├───┤┌───┐       │  ├───┤├───┤┌───┐       │  ├───┤├───┤┌───┐       │  »
# «q_1: ┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──┤ X ├┤ H ├┤ X ├───────■──»
# «     ├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐├───┤├───┤├───┤┌───┐┌─┴─┐»
# «q_2: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ H ├┤ X ├┤ H ├┤ X ├»
# «     └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘»
# «c: 3/══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «     ┌───┐┌───┐     ┌─┐
# «q_0: ┤ X ├┤ H ├─────┤M├──────
# «     ├───┤├───┤     └╥┘┌─┐
# «q_1: ┤ X ├┤ H ├──────╫─┤M├───
# «     ├───┤├───┤┌───┐ ║ └╥┘┌─┐
# «q_2: ┤ H ├┤ X ├┤ H ├─╫──╫─┤M├
# «     └───┘└───┘└───┘ ║  ║ └╥┘
# «c: 3/════════════════╩══╩══╩═
# «                     0  1  2

# %% [markdown]
# # Task 5: Experiment with Noise
# Add a noise model using Qiskit Aer’s NoiseModel and compare results with the ideal simulator.

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer
from qiskit_aer.noise import NoiseModel, depolarizing_error, ReadoutError

# --- Create Noise Model ---
noise_model = NoiseModel()

p_gate = 0.02   # Gate noise
p_read = 0.03   # Measurement noise

# Add gate noise
noise_model.add_all_qubit_quantum_error(depolarizing_error(p_gate, 1), ['x', 'h'])
noise_model.add_all_qubit_quantum_error(depolarizing_error(p_gate, 2), ['cx'])

# Add readout noise
readout_error = ReadoutError([
    [1 - p_read, p_read],
    [p_read, 1 - p_read]
])
noise_model.add_all_qubit_readout_error(readout_error)

# Backend
sim_noisy = Aer.get_backend('qasm_simulator')

# Transpile and run with noise
tqc = transpile(qc, sim_noisy)
result_noisy = sim_noisy.run(tqc, noise_model=noise_model, shots=2048).result()
counts_noisy = result_noisy.get_counts()

print("Noisy Result Counts:")
print(counts_noisy)
# Out:
# Noisy Result Counts:
# {'001': 218, '101': 601, '010': 194, '100': 193, '000': 188, '011': 202, '111': 226, '110': 226}

# %% [markdown]
# # Task 6: Real Hardware Execution (Optional)
# If you have IBM Quantum credentials, try running the same circuit on a real IBMQ backend and compare the histogram results.

# %%
from qiskit import transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

sim_ideal = Aer.get_backend('qasm_simulator')

# Ideal run (no noise)
tqc2 = transpile(qc, sim_ideal)
result_ideal = sim_ideal.run(tqc2, shots=2048).result()
counts_ideal = result_ideal.get_counts()

# Compare
plot_histogram([counts_ideal, counts_noisy], legend=['Ideal', 'Noisy'])
